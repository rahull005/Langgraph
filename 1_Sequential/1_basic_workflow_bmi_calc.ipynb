# %%
"""
1.define the state type
2.define the function for graph nodes
3. create the graph and add nodes
4. add edges to the graph
5. compile the graph into a workflow
"""

# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict

# %%
class BMIState(TypedDict):
    weight: float
    height: float
    bmi: float

# %%
def calculate_bmi(state: BMIState) -> BMIState:
    weight = state["weight"]
    height = state["height"]
    bmi = weight / (height ** 2)
    state["bmi"] = round(bmi, 2)
    return state

# %%
#define the state graph
graph = StateGraph(BMIState)

# %%
#define the nodes in the graph
graph.add_node('calculate_bmi', calculate_bmi)

# %%
#defining the edges in the graph
graph.add_edge(START, 'calculate_bmi')
graph.add_edge('calculate_bmi', END)

# %%
#compile the graph
workflow = graph.compile()

# %%
#invoke the graph with initial state
# execute the graph
initial_state = {'weight':80, 'height':1.73}

final_state = workflow.invoke(initial_state)

print(final_state)
# Out:
# {'weight': 80, 'height': 1.73, 'bmi': 26.73}
